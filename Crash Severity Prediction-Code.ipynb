# %%
import pandas as pd

# %%
# to increase the output width
pd.options.display.width= None
pd.options.display.max_columns= None
pd.set_option('display.max_rows', 40)
pd.set_option('display.max_columns', 40)

# %%
#to load the dataset
df1 = pd.read_csv("Young_Driver_Crashes.csv")
df2 = pd.read_csv("Fatal_Crashes.csv")
df3 = pd.read_csv("Older_Driver_Crashes.csv")

df4= df3[(df3['MostSevereInjury'] == 'K')|(df3['MostSevereInjury'] == 'C')|\
         (df3['MostSevereInjury'] == 'B') | (df3['MostSevereInjury'] == 'A')]
    
df5 = pd.read_csv("Distracted_Driver_Crashes.csv")
df6= df5[(df5['MostSevereInjury'] == 'K')|(df5['MostSevereInjury'] == 'C')|\
         (df5['MostSevereInjury'] == 'B') | (df5['MostSevereInjury'] == 'A')]

df7 = pd.read_csv("Car_Seat_Crashes.csv")
df8= df7[(df7['MostSevereInjury'] == 'K')|(df7['MostSevereInjury'] == 'C')|\
         (df7['MostSevereInjury'] == 'B') | (df7['MostSevereInjury'] == 'A')]

df9 = pd.read_csv("Wrong_Way_Crashes.csv")
df10= df9[(df9['MostSevereInjury'] == 'K')|(df9['MostSevereInjury'] == 'C')|\
         (df9['MostSevereInjury'] == 'B') | (df9['MostSevereInjury'] == 'A')]
    
df11 = pd.read_csv("Unlicensed_Driver_Crashes.csv")
df12= df11[(df11['MostSevereInjury'] == 'K')|(df11['MostSevereInjury'] == 'C')|\
         (df11['MostSevereInjury'] == 'B') | (df11['MostSevereInjury'] == 'A')]
    
df13 = pd.read_csv("Aggressive_Driving_Crashes.csv")
df14= df13[(df13['MostSevereInjury'] == 'K')|(df13['MostSevereInjury'] == 'C')|\
         (df13['MostSevereInjury'] == 'B') | (df13['MostSevereInjury'] == 'A')]
    
df15 = pd.read_csv("Roadway_Departure_Crashes.csv")
df16= df15[(df15['MostSevereInjury'] == 'K')|(df15['MostSevereInjury'] == 'C')|\
         (df15['MostSevereInjury'] == 'B') | (df15['MostSevereInjury'] == 'A')]

df17 = pd.read_csv("Motor_Coach.csv")
df18= df17[(df17['MostSevereInjury'] == 'K')|(df17['MostSevereInjury'] == 'C')|\
         (df17['MostSevereInjury'] == 'B') | (df17['MostSevereInjury'] == 'A')]

df19 = pd.read_csv("FMCSA_Crashes.csv")
df20= df19[(df19['MostSevereInjury'] == 'K')|(df19['MostSevereInjury'] == 'C')|\
         (df19['MostSevereInjury'] == 'B') | (df19['MostSevereInjury'] == 'A')]  

df21 = pd.read_csv("DUI_Crashes.csv")
df22= df21[(df21['MostSevereInjury'] == 'K')|(df21['MostSevereInjury'] == 'C')|\
         (df21['MostSevereInjury'] == 'B') | (df21['MostSevereInjury'] == 'A')]  

df23 = pd.read_csv("Intersection_Crashes.csv")
df24= df23[(df23['MostSevereInjury'] == 'K')|(df23['MostSevereInjury'] == 'C')|\
         (df23['MostSevereInjury'] == 'B') | (df23['MostSevereInjury'] == 'A')]  

df25 = pd.read_csv("Railroad_Crashes.csv")
df26= df25[(df25['MostSevereInjury'] == 'K')|(df25['MostSevereInjury'] == 'A')|\
         (df25['MostSevereInjury'] == 'B')]  

df27 = pd.read_csv("Motorcycle_Crashes.csv")
df28= df27[(df27['MostSevereInjury'] == 'K')|(df27['MostSevereInjury'] == 'A')|\
         (df27['MostSevereInjury'] == 'B')]  
    
df29 = pd.read_csv("Work_Zone_Crashes.csv")
df30= df29[(df29['MostSevereInjury'] == 'K')|(df29['MostSevereInjury'] == 'A')|\
         (df29['MostSevereInjury'] == 'B')]  

df31 = pd.read_csv("Pedestrian_Crashes.csv")
df32= df31[(df31['MostSevereInjury'] == 'K')|(df31['MostSevereInjury'] == 'A')|\
         (df31['MostSevereInjury'] == 'B')]  
    
df33 = pd.read_csv("Speeding_Crashes.csv")
df34= df33[(df33['MostSevereInjury'] == 'K')|(df33['MostSevereInjury'] == 'A')|\
         (df33['MostSevereInjury'] == 'B')]  
   
df35 = pd.read_csv("ATV_Crashes.csv")
df36= df35[(df35['MostSevereInjury'] == 'K')|(df35['MostSevereInjury'] == 'A')|\
         (df35['MostSevereInjury'] == 'B')]    

df37 = pd.read_csv("Fixed_Object_Crashes.csv")
df38= df37[(df37['MostSevereInjury'] == 'K')|(df37['MostSevereInjury'] == 'A')|\
         (df37['MostSevereInjury'] == 'B')]        
    
df39 = pd.read_csv("Non_Motorist.csv")
df40= df39[(df39['MostSevereInjury'] == 'K')|(df39['MostSevereInjury'] == 'A')|\
         (df39['MostSevereInjury'] == 'B')]     
    
df41 = pd.read_csv("Transit_Bus_Crashes.csv")
df42= df41[(df41['MostSevereInjury'] == 'K')|(df41['MostSevereInjury'] == 'A')|\
         (df41['MostSevereInjury'] == 'B')]     

df43 = pd.read_csv("Driver_And_Pedestrian_65_And_Over.csv")
df44= df43[(df43['MostSevereInjury'] == 'K')|(df43['MostSevereInjury'] == 'A')|\
         (df43['MostSevereInjury'] == 'B')] 

df45 = pd.read_csv("Bike_Crashes.csv")
df46= df45[(df45['MostSevereInjury'] == 'K')|(df45['MostSevereInjury'] == 'A')|\
         (df45['MostSevereInjury'] == 'B')] 
  
    
crash = pd.concat([df1,df2,df4,df6,df8,df10,df12,df14,df16,df18,df20,df22,df24,df26,df28,\
                   df30,df32,df34,df36,df38,df40,df42,df44,df46])

# %%
crash.head()
# Out:
#               X              Y  CrashID               CrashDate  \
# 0  1.028765e+06  673350.033186      676  2015/01/01 05:00:00+00
# 1  8.196822e+05  721128.329447      679  2015/01/03 05:00:00+00
# 2  8.261776e+05  728439.568925      680  2015/01/03 05:00:00+00
# 3  1.239798e+06  693342.339737      687  2015/01/03 05:00:00+00
# 4  8.257298e+05  731467.964574      707  2015/01/08 05:00:00+00
#
#    CrashTimeHour  CrashDateMonth  CrashDateYear DayofWeek  DayofWeekNumeric  \
# 0           19.0               1           2015  Thursday                 5
# 1           12.0               1           2015  Saturday                 7
# 2           19.0               1           2015  Saturday                 7
# 3           11.0               1           2015  Saturday                 7
# 4           15.0               1           2015  Thursday                 5
#
#   CrashTownName  NameOfRoadway NameOfIntersectingRoadway  \
# 0      Guilford    MURRAY LANE                       NaN
# 1    Brookfield     FEDERAL RD                       NaN
# 2    Brookfield  WHISCONIER RD             WHITE PINE DR
# 3    Stonington  GREENHAVEN RD                       NaN
# 4    Brookfield    OBTUSE HILL      ENT TO CENTER SCHOOL
#
#    CrashSpecificLocation CrashSpecificLocationDesc CrashSeverity  \
# 0                      1              Non-Junction             O
# 1                      1              Non-Junction             O
# 2                      1              Non-Junction             O
# 3                      1              Non-Junction             A
# 4                      9   Driveway Access-Related             O
#
#                                CrashSeverityDesc  WeatherCondition1  \
# 0                           Property Damage Only                1.0
# 1                           Property Damage Only                2.0
# 2                           Property Damage Only                7.0
# 3  Injury of any type (Serious, Minor, Possible)                1.0
# 4                           Property Damage Only                1.0
#
#   WeatherConditionDesc  FirstHarmfulEvent       FirstHarmfulEventDesc  ...  \
# 0                Clear                 37                     Mailbox  ...
# 1               Cloudy                 14  Motor Vehicle in Operation  ...
# 2                 Snow                 33  Utility Pole/Light Support  ...
# 3                Clear                 14  Motor Vehicle in Operation  ...
# 4                Clear                 34        Traffic Sign Support  ...
#
#    MostSevereInjury    MostSevereInjuryDesc RouteClass RouteClassDesc  \
# 0                 O  No Apparent Injury (O)        4.0          Local
# 1                 O  No Apparent Injury (O)        2.0        USRoute
# 2                 O  No Apparent Injury (O)        3.0          State
# 3                 C     Possible Injury (C)        4.0          Local
# 4                 O  No Apparent Injury (O)        3.0          State
#
#    MannerOfCrashCollisionImpact MannerCollisionImpactDesc  \
# 0                            88            Not Applicable
# 1                             1             Front to rear
# 2                            88            Not Applicable
# 3                             1             Front to rear
# 4                            88            Not Applicable
#
#    TrafficwayClassType TrafficwayClassTypeDesc  LawEnforcementAgencyName  \
# 0                    1     Trafficway, On Road               Guilford PD
# 1                    1     Trafficway, On Road             Brookfield PD
# 2                    1     Trafficway, On Road             Brookfield PD
# 3                    1     Trafficway, On Road             Stonington PD
# 4                    1     Trafficway, On Road             Brookfield PD
#
#   TypeOfIntersection TypeOfIntersectionDesc  LightCondition  \
# 0                  1    Not at Intersection               4
# 1                  1    Not at Intersection               1
# 2                  1    Not at Intersection               4
# 3                  1    Not at Intersection               1
# 4                  1    Not at Intersection               1
#
#   LightConditionDesc  TrafficSurfaceCondition TrafficSurfaceConditionDesc  \
# 0       Dark-Lighted                        1                         Dry
# 1           Daylight                        1                         Dry
# 2       Dark-Lighted                        3                        Snow
# 3           Daylight                        1                         Dry
# 4           Daylight                        1                         Dry
#
#    IsCrashRelatedToAWorkZone IsCrashRelatedToAWorkZoneDesc  \
# 0                        1.0                            No
# 1                        1.0                            No
# 2                        1.0                            No
# 3                        1.0                            No
# 4                        1.0                            No
#
#    TrafficwayDescription TrafficwayDescriptionText  DriverPedestrian
# 0                    NaN                       NaN               NaN
# 1                    NaN                       NaN               NaN
# 2                    NaN                       NaN               NaN
# 3                    NaN                       NaN               NaN
# 4                    NaN                       NaN               NaN
#
# [5 rows x 42 columns]

# %%
crash.shape
# Out:
# (660187, 42)

# %%
crash.dtypes
# Out:
# X                                float64
# Y                                float64
# CrashID                            int64
# CrashDate                         object
# CrashTimeHour                    float64
#                                   ...
# IsCrashRelatedToAWorkZone        float64
# IsCrashRelatedToAWorkZoneDesc     object
# TrafficwayDescription            float64
# TrafficwayDescriptionText         object
# DriverPedestrian                 float64
# Length: 42, dtype: object

# %%
crash = crash.drop_duplicates()
crash = crash.reset_index(drop=True)
crash = crash.sort_values(by = 'CrashID')

# %%
class_count_0, class_count_1,class_count_2,class_count_3,class_count_4 = crash['MostSevereInjury'].value_counts(ascending=True)
print(class_count_0)
print(class_count_1)
print(class_count_2)
print(class_count_3)
print(class_count_4)
# Out:
# 2739
# 11645
# 93479
# 101702
# 194307

# %%
# show the resultant Dataframe
crash.shape
# Out:
# (403876, 42)

# %%
#delete the columns with more than 50% null values and those columns that are irrelevant
crash = crash.drop(columns=['NameOfIntersectingRoadway','RouteClass',\
                            'RouteClassDesc','DriverPedestrian','LawEnforcementAgencyName'])

# %%
ctabres=pd.crosstab(index=crash['LightConditionDesc'],columns=crash['LightCondition'])
print(ctabres)
# Out:
# LightCondition             1     2     3      4      5     6    97   99
# LightConditionDesc
# Dark-Lighted                0     0     0  85200      0     0    0    0
# Dark-Not Lighted            0     0     0      0  26346     0    0    0
# Dark-Unknown Lighting       0     0     0      0      0  1906    0    0
# Dawn                        0  2704     0      0      0     0    0    0
# Daylight               279751     0     0      0      0     0    0    0
# Dusk                        0     0  6511      0      0     0    0    0
# Other                       0     0     0      0      0     0  521    0
# Unknown                     0     0     0      0      0     0    0  937

# %%
# importing the required function
from scipy.stats import chi2_contingency

# %%
# Performing Chi-sq test
ChiSqResult = chi2_contingency(ctabres)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# The P-Value of the ChiSq Test is: 0.0

# %%
#Unnecessary columns
crash = crash.drop(columns=['CrashID','CrashDate','X','Y','NameOfRoadway','DayofWeekNumeric',\
                            'CrashSpecificLocation','CrashSeverity','WeatherCondition1',\
                              'FirstHarmfulEvent','SchoolBusRelated','MostSevereInjury',\
                                'MannerOfCrashCollisionImpact','TrafficwayClassType',\
                                    'TypeOfIntersection','LightCondition',\
                                        'TrafficSurfaceCondition','TrafficwayDescription',\
                                            'TrafficwayDescriptionText',\
                                            'IsCrashRelatedToAWorkZone'])

# %%
print(crash.shape)
# Out:
# (403876, 17)

# %%
print(crash.isnull().sum())
# Out:
# CrashTimeHour                    0
# CrashDateMonth                   0
# CrashDateYear                    0
# DayofWeek                        0
# CrashTownName                    0
# CrashSpecificLocationDesc        0
# CrashSeverityDesc                0
# WeatherConditionDesc             0
# FirstHarmfulEventDesc            1
# SchoolBusRelatedDesc             0
# MostSevereInjuryDesc             4
# MannerCollisionImpactDesc        0
# TrafficwayClassTypeDesc          0
# TypeOfIntersectionDesc           0
# LightConditionDesc               0
# TrafficSurfaceConditionDesc      0
# IsCrashRelatedToAWorkZoneDesc    5
# dtype: int64

# %%
crash = crash.dropna()

# %%
print(crash['CrashTownName'].unique())
print(crash['CrashTownName'].nunique())
# Out:
# ['Guilford' 'Brookfield' 'Stonington' 'EastWindsor' 'East Windsor'
#  'Suffield' 'New Milford' 'Plainville' 'Windham' 'Norwich' 'Vernon'
#  'Glastonbury' 'Cromwell' 'Danbury' 'Bethel' 'East Haven' 'EastHaven'
#  'Farmington' 'Hamden' 'Shelton' 'West Hartford' 'WestHartford'
#  'NorthHaven' 'North Haven' 'Berlin' 'Orange' 'Enfield' 'Groton' 'Bristol'
#  'Madison' 'Norwalk' 'Stamford' 'Simsbury' 'Avon' 'East Hartford'
#  'EastHartford' 'Granby' 'Ridgefield' 'Monroe' 'Milford' 'Clinton'
#  'Old Saybrook' 'Waterford' 'NewLondon' 'Plainfield' 'New London'
#  'Newtown' 'Wethersfield' 'Seymour' 'Southington' 'Weston' 'Windsor Locks'
#  'Middlebury' 'Newington' 'Cheshire' 'New Haven' 'New Canaan' 'NewCanaan'
#  'Rocky Hill' 'RockyHill' 'Portland' 'Easton' 'Waterbury' 'Coventry'
#  'East Hampton' 'Bridgeport' 'New Britain' 'NewBritain' 'South Windsor'
#  'SouthWindsor' 'Fairfield' 'Plymouth' 'Ellington' 'Killingly' 'Sharon'
#  'Hartford' 'Chaplin' 'Montville' 'Goshen' 'North Canaan' 'Ledyard'
#  'Meriden' 'Colchester' 'Westport' 'Woodstock' 'Greenwich' 'Putnam'
#  'Manchester' 'Old Lyme' 'OldLyme' 'Haddam' 'Darien' 'Andover' 'Tolland'
#  'Marlborough' 'Windsor' 'Southbury' 'Somers' 'Stratford' 'Trumbull'
#  'New Hartford' 'Thompson' 'Hampton' 'Derby' 'Middletown' 'Mansfield'
#  'Griswold' 'Bolton' 'Washington' 'Pomfret' 'Essex' 'Sprague' 'Oxford'
#  'Wallingford' 'Brooklyn' 'Barkhamsted' 'Harwinton' 'Woodbridge'
#  'Prospect' 'Canterbury' 'North Stonington' 'East Granby' 'Ashford'
#  'Roxbury' 'Voluntown' 'Burlington' 'Warren' 'Franklin' 'Canaan' 'Bethany'
#  'Salisbury' 'Torrington' 'Stafford' 'Columbia' 'Preston' 'EastHaddam'
#  'Kent' 'Woodbury' 'Morris' 'Bethlehem' 'Watertown' 'New Fairfield'
#  'West Haven' 'East Lyme' 'Thomaston' 'Naugatuck' 'Middlefield' 'Bozrah'
#  'NewFairfield' 'Chester' 'Salem' 'Sherman' 'Durham' 'Hebron' 'Branford'
#  'Beacon Falls' 'Eastford' 'East Haddam' 'Litchfield' 'Lisbon' 'Westbrook'
#  'Cornwall' 'Ansonia' 'Deep River' 'NorthStonington' 'Lebanon'
#  'Willington' 'NewHaven' 'Norfolk' 'Killingworth' 'Union' 'NewHartford'
#  'Colebrook' 'Bridgewater' 'NorthBranford' 'North Branford' 'Scotland'
#  'Sterling' 'Hartland' 'NorthCanaan' 'Winchester' 'WindsorLocks'
#  'NewMilford' 'EastLyme' 'WestHaven' 'Redding' 'Wolcott' 'Bloomfield'
#  'OldSaybrook' 'Canton' 'DeepRiver' 'Wilton' 'Lyme' 'BeaconFalls'
#  'EastGranby' 'EastHampton' 'Mashantucket']
# 197

# %%
crash['CrashTownName'] = crash['CrashTownName'].replace \
    (['EastHaven', 'WestHartford','NorthHaven','EastHartford',\
      'NewLondon','NewHaven','EastWindsor','NewBritain','NewCanaan',\
          'RockyHill','SouthWindsor','NewFairfield','NorthCanaan',\
              'NorthBranford','WindsorLocks','OldSaybrook','OldLyme',\
                  'EastHampton','NorthStonington','NewHartford','NewMilford',\
                      'EastLyme','EastHaddam','BeaconFalls','EastGranby',\
                          'WestHaven','DeepRiver'],\
     ['East Haven','West Hartford','North Haven','East Hartford',\
      'New London','New Haven','East Windsor','New Britain','New Canaan',\
          'Rocky Hill','South Windsor','New Fairfield','North Canaan',\
              'North Branford','Windsor Locks','Old Saybrook','Old Lyme',\
                'East Hampton','North Stonington','New Hartford', 'New Milford',\
                    'East Lyme','East Haddam','Beacon Falls','East Granby',\
                        'West Haven','Deep River']
         )

# %%
crash.drop(crash[(crash['MostSevereInjuryDesc'] == 'No Apparent Injury (O)') &\
                 ((crash['MannerCollisionImpactDesc'] == 'Unknown')|\
                     (crash['LightConditionDesc'] == 'Unknown')|\
                         (crash['TrafficSurfaceConditionDesc'] == 'Unknown')|\
                             (crash['FirstHarmfulEventDesc'] == 'Unknown')|\
                                 (crash['TypeOfIntersectionDesc'] == 'Unknown')|\
                                     (crash['SchoolBusRelatedDesc'] == 'Unknown')|\
                                         (crash['CrashSpecificLocationDesc'] == 'Unknown')|\
                                             (crash['TrafficwayClassTypeDesc'] == 'Unknown')|\
                                                 (crash['IsCrashRelatedToAWorkZoneDesc'] == 'Unknown'))].index, inplace=True)

# %%
crash.drop(crash[(crash['MostSevereInjuryDesc'] == 'No Apparent Injury (O)') &\
                 ((crash['MannerCollisionImpactDesc'] == 'Not Applicable')|\
                     (crash['LightConditionDesc'] == 'Not Applicable')|\
                         (crash['TrafficSurfaceConditionDesc'] == 'Not Applicable')|\
                             (crash['FirstHarmfulEventDesc'] == 'Not Applicable')|\
                                 (crash['TypeOfIntersectionDesc'] == 'Not Applicable')|\
                                     (crash['SchoolBusRelatedDesc'] == 'Not Applicable')|\
                                         (crash['CrashSpecificLocationDesc'] == 'Not Applicable')|\
                                             (crash['TrafficwayClassTypeDesc'] == 'Not Applicable')|\
                                                 (crash['IsCrashRelatedToAWorkZoneDesc'] == 'Not Applicable'))].index, inplace=True)

# %%
class_count_0, class_count_1,class_count_2,class_count_3,class_count_4 = crash['MostSevereInjuryDesc'].value_counts(ascending=True)
print(class_count_0)
print(class_count_1)
print(class_count_2)
print(class_count_3)
print(class_count_4)
# Out:
# 2739
# 11645
# 93479
# 101702
# 159964

# %%
crash.shape
# Out:
# (369529, 17)

# %%
crash.to_csv('accidentrecord.csv')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
crash['CrashTimeHour_cat'] = le.fit_transform(crash['CrashTimeHour'])
crash['CrashDateMonth_cat'] = le.fit_transform(crash['CrashDateMonth'])
crash['CrashDateYear_cat'] = le.fit_transform(crash['CrashDateYear'])
crash['DayofWeek_cat'] = le.fit_transform(crash['DayofWeek'])
crash['CrashTownName_cat'] = le.fit_transform(crash['CrashTownName'])
crash['CrashSpecificLocationDesc_cat'] = le.fit_transform(crash['CrashSpecificLocationDesc'])
crash['MostSevereInjuryDesc_cat'] = le.fit_transform(crash['MostSevereInjuryDesc'])
crash['WeatherConditionDesc_cat'] = le.fit_transform(crash['WeatherConditionDesc'])
crash['FirstHarmfulEventDesc_cat'] = le.fit_transform(crash['FirstHarmfulEventDesc'])
crash['SchoolBusRelatedDesc_cat'] = le.fit_transform(crash['SchoolBusRelatedDesc'])
crash['MannerCollisionImpactDesc_cat'] = le.fit_transform(crash['MannerCollisionImpactDesc'])
crash['TrafficwayClassTypeDesc_cat'] = le.fit_transform(crash['TrafficwayClassTypeDesc'])
crash['TypeOfIntersectionDesc_cat'] = le.fit_transform(crash['TypeOfIntersectionDesc'])
crash['LightConditionDesc_cat'] = le.fit_transform(crash['LightConditionDesc'])
crash['TrafficSurfaceConditionDesc_cat'] = le.fit_transform(crash['TrafficSurfaceConditionDesc'])
crash['IsCrashRelatedToAWorkZoneDesc_cat'] = le.fit_transform(crash['IsCrashRelatedToAWorkZoneDesc'])

# %%
crash.head(10)
# Out:
#         CrashTimeHour  CrashDateMonth  CrashDateYear  DayofWeek CrashTownName  \
# 1                12.0               1           2015   Saturday    Brookfield
# 3                11.0               1           2015   Saturday    Stonington
# 353855           16.0               1           2015   Saturday      Guilford
# 312389           17.0               1           2015     Monday    Brookfield
# 353856            4.0               1           2015     Monday  East Windsor
# 353857            7.0               1           2015     Sunday    Brookfield
# 353858            5.0               1           2015     Monday  East Windsor
# 265088           13.0               1           2015  Wednesday      Suffield
# 299493           15.0               1           2015   Saturday    Brookfield
# 5                10.0               1           2015     Monday    Brookfield
#
#        CrashSpecificLocationDesc  \
# 1                   Non-Junction
# 3                   Non-Junction
# 353855              Non-Junction
# 312389              Intersection
# 353856                     Other
# 353857              Non-Junction
# 353858              Non-Junction
# 265088              Intersection
# 299493              Non-Junction
# 5                   Non-Junction
#
#                                     CrashSeverityDesc WeatherConditionDesc  \
# 1                                Property Damage Only               Cloudy
# 3       Injury of any type (Serious, Minor, Possible)                Clear
# 353855  Injury of any type (Serious, Minor, Possible)                 Snow
# 312389  Injury of any type (Serious, Minor, Possible)                Clear
# 353856  Injury of any type (Serious, Minor, Possible)                Clear
# 353857  Injury of any type (Serious, Minor, Possible)                 Rain
# 353858  Injury of any type (Serious, Minor, Possible)                Clear
# 265088  Injury of any type (Serious, Minor, Possible)                 Snow
# 299493  Injury of any type (Serious, Minor, Possible)                Clear
# 5                                Property Damage Only                 Rain
#
#              FirstHarmfulEventDesc SchoolBusRelatedDesc  \
# 1       Motor Vehicle in Operation                   No
# 3       Motor Vehicle in Operation                   No
# 353855  Utility Pole/Light Support                   No
# 312389  Motor Vehicle in Operation                   No
# 353856             Tree (standing)                   No
# 353857                        Curb                   No
# 353858                  Embankment                   No
# 265088  Motor Vehicle in Operation                   No
# 299493  Motor Vehicle in Operation                   No
# 5       Motor Vehicle in Operation                   No
#
#               MostSevereInjuryDesc MannerCollisionImpactDesc  \
# 1           No Apparent Injury (O)             Front to rear
# 3              Possible Injury (C)             Front to rear
# 353855         Possible Injury (C)            Not Applicable
# 312389         Possible Injury (C)             Front to rear
# 353856  Suspected Minor Injury (B)            Not Applicable
# 353857         Possible Injury (C)            Not Applicable
# 353858  Suspected Minor Injury (B)            Not Applicable
# 265088         Possible Injury (C)                     Angle
# 299493         Possible Injury (C)             Front to rear
# 5           No Apparent Injury (O)             Front to rear
#
#         TrafficwayClassTypeDesc TypeOfIntersectionDesc LightConditionDesc  \
# 1           Trafficway, On Road    Not at Intersection           Daylight
# 3           Trafficway, On Road    Not at Intersection           Daylight
# 353855  Trafficway, Not on Road    Not at Intersection           Daylight
# 312389      Trafficway, On Road         T-Intersection       Dark-Lighted
# 353856           Non-trafficway    Not at Intersection       Dark-Lighted
# 353857      Trafficway, On Road    Not at Intersection           Daylight
# 353858      Trafficway, On Road    Not at Intersection   Dark-Not Lighted
# 265088      Trafficway, On Road         T-Intersection           Daylight
# 299493      Trafficway, On Road    Not at Intersection           Daylight
# 5           Trafficway, On Road    Not at Intersection           Daylight
#
#        TrafficSurfaceConditionDesc IsCrashRelatedToAWorkZoneDesc  \
# 1                              Dry                            No
# 3                              Dry                            No
# 353855                        Snow                            No
# 312389                         Dry                            No
# 353856                 Ice / Frost                            No
# 353857                       Slush                            No
# 353858                 Ice / Frost                            No
# 265088                         Wet                            No
# 299493                         Dry                            No
# 5                              Wet                            No
#
#         CrashTimeHour_cat  CrashDateMonth_cat  CrashDateYear_cat  \
# 1                      12                   0                  0
# 3                      11                   0                  0
# 353855                 16                   0                  0
# 312389                 17                   0                  0
# 353856                  4                   0                  0
# 353857                  7                   0                  0
# 353858                  5                   0                  0
# 265088                 13                   0                  0
# 299493                 15                   0                  0
# 5                      10                   0                  0
#
#         DayofWeek_cat  CrashTownName_cat  CrashSpecificLocationDesc_cat  \
# 1                   2                 17                              9
# 3                   2                137                              9
# 353855              2                 59                              9
# 312389              1                 17                              7
# 353856              1                 44                             11
# 353857              3                 17                              9
# 353858              1                 44                              9
# 265088              6                139                              7
# 299493              2                 17                              9
# 5                   1                 17                              9
#
#         MostSevereInjuryDesc_cat  WeatherConditionDesc_cat  \
# 1                              1                         3
# 3                              2                         2
# 353855                         2                        11
# 312389                         2                         2
# 353856                         3                         2
# 353857                         2                         8
# 353858                         3                         2
# 265088                         2                        11
# 299493                         2                         2
# 5                              1                         8
#
#         FirstHarmfulEventDesc_cat  SchoolBusRelatedDesc_cat  \
# 1                              21                         0
# 3                              21                         0
# 353855                         39                         0
# 312389                         21                         0
# 353856                         37                         0
# 353857                          8                         0
# 353858                         11                         0
# 265088                         21                         0
# 299493                         21                         0
# 5                              21                         0
#
#         MannerCollisionImpactDesc_cat  TrafficwayClassTypeDesc_cat  \
# 1                                   2                            3
# 3                                   2                            3
# 353855                              3                            2
# 312389                              2                            3
# 353856                              3                            0
# 353857                              3                            3
# 353858                              3                            3
# 265088                              0                            3
# 299493                              2                            3
# 5                                   2                            3
#
#         TypeOfIntersectionDesc_cat  LightConditionDesc_cat  \
# 1                                3                       4
# 3                                3                       4
# 353855                           3                       4
# 312389                           5                       0
# 353856                           3                       0
# 353857                           3                       4
# 353858                           3                       1
# 265088                           5                       4
# 299493                           3                       4
# 5                                3                       4
#
#         TrafficSurfaceConditionDesc_cat  IsCrashRelatedToAWorkZoneDesc_cat
# 1                                     0                                  0
# 3                                     0                                  0
# 353855                                8                                  0
# 312389                                0                                  0
# 353856                                1                                  0
# 353857                                7                                  0
# 353858                                1                                  0
# 265088                               11                                  0
# 299493                                0                                  0
# 5                                    11                                  0

# %%
from sklearn.preprocessing import LabelEncoder
# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column
crash['CrashSeverityDesc_Cat'] = labelencoder.fit_transform(crash['CrashSeverityDesc'])

# %%
crash=crash.drop(columns =['CrashTimeHour','CrashDateMonth','CrashDateYear','DayofWeek',\
        'CrashTownName','CrashSpecificLocationDesc','MostSevereInjuryDesc',\
          'CrashSeverityDesc','WeatherConditionDesc','FirstHarmfulEventDesc',\
              'SchoolBusRelatedDesc','MannerCollisionImpactDesc',\
                  'TrafficwayClassTypeDesc','TypeOfIntersectionDesc','LightConditionDesc',\
                      'TrafficSurfaceConditionDesc','IsCrashRelatedToAWorkZoneDesc' ])

# %%
print(crash.isnull().sum())
# Out:
# CrashTimeHour_cat                    0
# CrashDateMonth_cat                   0
# CrashDateYear_cat                    0
# DayofWeek_cat                        0
# CrashTownName_cat                    0
# CrashSpecificLocationDesc_cat        0
# MostSevereInjuryDesc_cat             0
# WeatherConditionDesc_cat             0
# FirstHarmfulEventDesc_cat            0
# SchoolBusRelatedDesc_cat             0
# MannerCollisionImpactDesc_cat        0
# TrafficwayClassTypeDesc_cat          0
# TypeOfIntersectionDesc_cat           0
# LightConditionDesc_cat               0
# TrafficSurfaceConditionDesc_cat      0
# IsCrashRelatedToAWorkZoneDesc_cat    0
# CrashSeverityDesc_Cat                0
# dtype: int64

# %%
cor=crash.corr()
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
crash=crash.drop(columns =['MostSevereInjuryDesc_cat'])

# %%
print(crash.isnull().sum())
# Out:
# CrashTimeHour_cat                    0
# CrashDateMonth_cat                   0
# CrashDateYear_cat                    0
# DayofWeek_cat                        0
# CrashTownName_cat                    0
# CrashSpecificLocationDesc_cat        0
# WeatherConditionDesc_cat             0
# FirstHarmfulEventDesc_cat            0
# SchoolBusRelatedDesc_cat             0
# MannerCollisionImpactDesc_cat        0
# TrafficwayClassTypeDesc_cat          0
# TypeOfIntersectionDesc_cat           0
# LightConditionDesc_cat               0
# TrafficSurfaceConditionDesc_cat      0
# IsCrashRelatedToAWorkZoneDesc_cat    0
# CrashSeverityDesc_Cat                0
# dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X1 = crash.drop(columns = ['CrashSeverityDesc_Cat'])

y1 = crash['CrashSeverityDesc_Cat']

chi_scores = chi2(X1,y1)
chi_scores
# Out:
# (array([1.11086134e+03, 2.65570060e+02, 1.27793897e+03, 1.45644607e+01,
#         3.56351044e+02, 2.75445081e+01, 4.14104442e+01, 3.47353417e+03,
#         7.53961410e+00, 1.33040108e+04, 4.97350787e-01, 1.13924539e+02,
#         1.39109808e+03, 6.47782217e+01, 5.64139113e+01]),
#  array([6.01901766e-242, 2.14879109e-058, 3.15557805e-278, 6.87650146e-004,
#         4.16249779e-078, 1.04420573e-006, 1.01820749e-009, 0.00000000e+000,
#         2.30565116e-002, 0.00000000e+000, 7.79833071e-001, 1.82642027e-025,
#         8.45065673e-303, 8.58198750e-015, 5.62179247e-013]))

# %%
selector = SelectKBest(chi2, k=10)
new_data = selector.fit(X1,y1)

# %%
# Get columns to keep and create new dataframe with those only
cols = selector.get_support(indices=True)
print(cols)
features_df_new = X1.iloc[:,cols]

new_data.scores_
# Out:
# [ 0  1  2  4  7  9 11 12 13 14]
# array([1.11086134e+03, 2.65570060e+02, 1.27793897e+03, 1.45644607e+01,
#        3.56351044e+02, 2.75445081e+01, 4.14104442e+01, 3.47353417e+03,
#        7.53961410e+00, 1.33040108e+04, 4.97350787e-01, 1.13924539e+02,
#        1.39109808e+03, 6.47782217e+01, 5.64139113e+01])

# %%
chi_values = pd.Series(chi_scores[0],index = X1.columns)
chi_values.sort_values(ascending = False , inplace = True)
chi_values.plot.bar()
# Out:
# <AxesSubplot:>

# %%
print(crash.isnull().sum())
# Out:
# CrashTimeHour_cat                    0
# CrashDateMonth_cat                   0
# CrashDateYear_cat                    0
# DayofWeek_cat                        0
# CrashTownName_cat                    0
# CrashSpecificLocationDesc_cat        0
# WeatherConditionDesc_cat             0
# FirstHarmfulEventDesc_cat            0
# SchoolBusRelatedDesc_cat             0
# MannerCollisionImpactDesc_cat        0
# TrafficwayClassTypeDesc_cat          0
# TypeOfIntersectionDesc_cat           0
# LightConditionDesc_cat               0
# TrafficSurfaceConditionDesc_cat      0
# IsCrashRelatedToAWorkZoneDesc_cat    0
# CrashSeverityDesc_Cat                0
# dtype: int64

# %%
cat_cols = ['CrashTimeHour_cat','CrashDateYear_cat','CrashDateMonth_cat',\
        'CrashSpecificLocationDesc_cat','CrashTownName_cat',\
          'FirstHarmfulEventDesc_cat',\
              'MannerCollisionImpactDesc_cat',\
                  'TypeOfIntersectionDesc_cat','LightConditionDesc_cat',\
                      'TrafficSurfaceConditionDesc_cat','WeatherConditionDesc_cat',\
                          'SchoolBusRelatedDesc_cat','TrafficwayClassTypeDesc_cat',\
                              'IsCrashRelatedToAWorkZoneDesc_cat']

# %%
cat_cols_encoded = []
for col in cat_cols:
  cat_cols_encoded += [f"{col[:]}_{cat}" for cat in list(crash[col].unique())]

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False,handle_unknown='ignore')
encoded_cols = onehot_encoder.fit_transform(crash[cat_cols])
df_enc = pd.DataFrame(encoded_cols,columns = cat_cols_encoded )
df_enc.shape
crash.shape
# Out:
# (369529, 16)

# %%
print(crash.isnull().sum())
# Out:
# CrashTimeHour_cat                    0
# CrashDateMonth_cat                   0
# CrashDateYear_cat                    0
# DayofWeek_cat                        0
# CrashTownName_cat                    0
# CrashSpecificLocationDesc_cat        0
# WeatherConditionDesc_cat             0
# FirstHarmfulEventDesc_cat            0
# SchoolBusRelatedDesc_cat             0
# MannerCollisionImpactDesc_cat        0
# TrafficwayClassTypeDesc_cat          0
# TypeOfIntersectionDesc_cat           0
# LightConditionDesc_cat               0
# TrafficSurfaceConditionDesc_cat      0
# IsCrashRelatedToAWorkZoneDesc_cat    0
# CrashSeverityDesc_Cat                0
# dtype: int64

# %%
crash = crash.drop(columns=['CrashTimeHour_cat','CrashDateMonth_cat','CrashDateYear_cat','DayofWeek_cat',\
        'CrashTownName_cat','CrashSpecificLocationDesc_cat',\
          'FirstHarmfulEventDesc_cat',\
              'SchoolBusRelatedDesc_cat','MannerCollisionImpactDesc_cat',\
                  'TrafficwayClassTypeDesc_cat','TypeOfIntersectionDesc_cat','LightConditionDesc_cat',\
                      'TrafficSurfaceConditionDesc_cat','IsCrashRelatedToAWorkZoneDesc_cat',\
                          'WeatherConditionDesc_cat'])

# %%
print(crash.isnull().sum())
crash.shape
# Out:
# CrashSeverityDesc_Cat    0
# dtype: int64
# (369529, 1)

# %%
crash = pd.concat([crash,df_enc],axis=1, join='inner',ignore_index=False)

# %%
print(crash.isnull().sum())
# Out:
# CrashSeverityDesc_Cat                  0
# CrashTimeHour_cat_12                   0
# CrashTimeHour_cat_11                   0
# CrashTimeHour_cat_16                   0
# CrashTimeHour_cat_17                   0
#                                       ..
# TrafficwayClassTypeDesc_cat_1          0
# TrafficwayClassTypeDesc_cat_4          0
# IsCrashRelatedToAWorkZoneDesc_cat_0    0
# IsCrashRelatedToAWorkZoneDesc_cat_2    0
# IsCrashRelatedToAWorkZoneDesc_cat_1    0
# Length: 339, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = crash.drop(columns = ['CrashSeverityDesc_Cat'])
y = crash['CrashSeverityDesc_Cat']

import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)
dataset =pd.DataFrame(scaled_data,columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(
             dataset, y, test_size = 0.25,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.metrics import classification_report_imbalanced
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
# Out:
# C:\Users\Sheba\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
from collections import Counter
counter1 = Counter(y_train)
print(counter1)
# Out:
# Counter({1: 129794, 2: 119958, 0: 1634})

# %%
strategy = {0:119958,1:129794,2:119958}
over = SMOTE(sampling_strategy=strategy)

strategy1 = {0:119958,1:119958,2:119958}
under = RandomUnderSampler(sampling_strategy=strategy1)

X_resampled, y_resampled = over.fit_resample(X_train, y_train)
X_resampled1, y_resampled1 = under.fit_resample(X_resampled, y_resampled)

# %%
counter = Counter(y_resampled)
print(counter)
counter2 = Counter(y_resampled1)
print(counter2)
# Out:
# Counter({1: 129794, 2: 119958, 0: 119958})
# Counter({0: 119958, 1: 119958, 2: 119958})

# %%
# Create a pipeline
model = RandomForestClassifier(n_estimators=100,class_weight="balanced")

# %%
model.fit(X_resampled1,y_resampled1)
model.fit(X_train,y_train)

print(classification_report_imbalanced(y_test, model.predict(X_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,  model.predict(X_test))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.43      0.25      1.00      0.32      0.50      0.23       576
#           1       0.89      0.63      0.91      0.74      0.76      0.56     43207
#           2       0.70      0.92      0.64      0.79      0.76      0.60     40013
#
# avg / total       0.79      0.77      0.78      0.76      0.76      0.58     83796
# array([[  143,   270,   163],
#        [  122, 27390, 15695],
#        [   65,  3285, 36663]], dtype=int64)

# %%
model = DecisionTreeClassifier(class_weight="balanced")
model.fit(X_resampled1,y_resampled1)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
print(classification_report_imbalanced(y_test, model.predict(X_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,  model.predict(X_test))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.28      0.34      0.99      0.31      0.58      0.32       576
#           1       0.74      0.70      0.74      0.72      0.72      0.51     43207
#           2       0.70      0.73      0.71      0.71      0.72      0.52     40013
#
# avg / total       0.71      0.71      0.72      0.71      0.72      0.51     83796
# array([[  196,   227,   153],
#        [  269, 30276, 12662],
#        [  226, 10524, 29263]], dtype=int64)

# %%
model = XGBClassifier()

model.fit(X_resampled1,y_resampled1)
model.fit(X_train,y_train)
# Out:
# C:\Users\Sheba\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\Sheba\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [17:20:36] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:39:07] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
print(classification_report_imbalanced(y_test, model.predict(X_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,  model.predict(X_test))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.55      0.16      1.00      0.25      0.40      0.14       576
#           1       0.98      0.60      0.99      0.75      0.77      0.57     43207
#           2       0.70      0.99      0.60      0.82      0.78      0.62     40013
#
# avg / total       0.84      0.79      0.80      0.78      0.77      0.59     83796
# array([[   91,   301,   184],
#        [   59, 26034, 17114],
#        [   16,   230, 39767]], dtype=int64)
